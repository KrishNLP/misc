# %%
from mobile import get_brands
import os
import glob
import pandas as pd

# %%
all_brands = get_brands()

# %%
all_brands.head()
# Out:
#                                               url    brand  n_models
# 0     https://www.gsmarena.com/acer-phones-59.php     Acer       100
# 1   https://www.gsmarena.com/alcatel-phones-5.php  alcatel       378
# 2  https://www.gsmarena.com/allview-phones-88.php  Allview       134
# 3   https://www.gsmarena.com/amazon-phones-76.php   Amazon        17
# 4     https://www.gsmarena.com/amoi-phones-28.php     Amoi        47

# %%
expected_n_models = all_brands.n_models.sum()
n_brands = all_brands.shape[0]
print (expected_n_models, n_brands)
# Out:
# 9505 110

# %%
if os.path.isdir('model_attributes'):
    print ('Results exist!')
# Out:
# Results exist!

# %%
all_results = glob.glob('model_attributes/*.json')
 # number of results matches brands
assert len(all_results) == n_brands, "Wrong number of brands"

# %%
from pandas.io.json import json_normalize
import json

test_fn = 'model_attributes/Acer_models.json'
io = open(test_fn, 'r')
to_json = [json.loads(line) for line in io] # new line per record
test_df = json_normalize(to_json)
# check acer brands
(test_df.shape, all_brands.loc[all_brands.brand == 'Acer'].n_models.values[0]) # matching n.models
# Out:
# ((100, 195), 100)

# %% [markdown]
# # Combining all data

# %%
from functools import reduce

def read_fp(fn): return [json.loads(line) for line in open(fn, 'r') if line]

all_records = list(map(read_fp, all_results))

# Mistakenly hardcoded brand name, stretching to work with zip, making amendments on fly
brand_names = [x.split('/')[-1].replace('_models.json','') for x in all_results]
stretched_brands = [[b] * len(objs) for b,objs in zip(brand_names, all_records)]
stretched_brands = [x for y in stretched_brands for x in y]

all_records = reduce(lambda x,y: x+y, all_records) # combining all lists
all_records = [{**r, **{'brand' : brand}} for r,brand in zip(all_records, stretched_brands)]

# %%
normalized = json_normalize(all_records) # flattens dictionaries into df

# %%
normalized.loc[normalized.err.notnull()].groupby(['err','brand']).size() # failed requests
# Out:
# err                                                  brand
# <urlopen error [Errno 54] Connection reset by peer>  O          1
#                                                      OnePlus    1
#                                                      Oppo       2
#                                                      Orange     2
#                                                      Samsung    1
# Remote end closed connection without response        Oppo       1
# dtype: int64

# %%
results_df = normalized.groupby('brand').size().rename('results_n').reset_index()
final_df = pd.merge(results_df, all_brands, on='brand')[['brand', 'url', 'results_n', 'n_models']]

# %%
final_df
# Out:
#                brand                                                url  \
# 0              AT&T;        https://www.gsmarena.com/at&t-phones-57.php
# 1               Acer        https://www.gsmarena.com/acer-phones-59.php
# 2            Allview     https://www.gsmarena.com/allview-phones-88.php
# 3             Amazon      https://www.gsmarena.com/amazon-phones-76.php
# 4               Amoi        https://www.gsmarena.com/amoi-phones-28.php
# 5              Apple       https://www.gsmarena.com/apple-phones-48.php
# 6             Archos      https://www.gsmarena.com/archos-phones-90.php
# 7               Asus        https://www.gsmarena.com/asus-phones-46.php
# 8                BLU         https://www.gsmarena.com/blu-phones-67.php
# 9                 BQ         https://www.gsmarena.com/bq-phones-108.php
# 10              BenQ        https://www.gsmarena.com/benq-phones-31.php
# 11      BenQ-Siemens  https://www.gsmarena.com/benq_siemens-phones-4...
# 12           Benefon     https://www.gsmarena.com/benefon-phones-15.php
# 13              Bird        https://www.gsmarena.com/bird-phones-34.php
# 14        BlackBerry  https://www.gsmarena.com/blackberry-phones-36.php
# 15         Blackview  https://www.gsmarena.com/blackview-phones-116.php
# 16             Bosch       https://www.gsmarena.com/bosch-phones-10.php
# 17             Casio       https://www.gsmarena.com/casio-phones-77.php
# 18               Cat         https://www.gsmarena.com/cat-phones-89.php
# 19            Celkon      https://www.gsmarena.com/celkon-phones-75.php
# 20              Chea        https://www.gsmarena.com/chea-phones-24.php
# 21           Coolpad    https://www.gsmarena.com/coolpad-phones-105.php
# 22              Dell        https://www.gsmarena.com/dell-phones-61.php
# 23           Emporia     https://www.gsmarena.com/emporia-phones-93.php
# 24         Energizer  https://www.gsmarena.com/energizer-phones-106.php
# 25          Ericsson     https://www.gsmarena.com/ericsson-phones-2.php
# 26              Eten        https://www.gsmarena.com/eten-phones-40.php
# 27   Fujitsu Siemens  https://www.gsmarena.com/fujitsu_siemens-phone...
# 28       Garmin-Asus  https://www.gsmarena.com/garmin_asus-phones-65...
# 29          Gigabyte    https://www.gsmarena.com/gigabyte-phones-47.php
# ..               ...                                                ...
# 80             Sharp       https://www.gsmarena.com/sharp-phones-23.php
# 81           Siemens      https://www.gsmarena.com/siemens-phones-3.php
# 82             Sonim       https://www.gsmarena.com/sonim-phones-54.php
# 83              Sony         https://www.gsmarena.com/sony-phones-7.php
# 84     Sony Ericsson  https://www.gsmarena.com/sony_ericsson-phones-...
# 85             Spice       https://www.gsmarena.com/spice-phones-68.php
# 86          T-Mobile    https://www.gsmarena.com/t_mobile-phones-55.php
# 87           Tel.Me.     https://www.gsmarena.com/tel_me_-phones-21.php
# 88             Telit       https://www.gsmarena.com/telit-phones-16.php
# 89           Thuraya     https://www.gsmarena.com/thuraya-phones-49.php
# 90           Toshiba     https://www.gsmarena.com/toshiba-phones-44.php
# 91           Unnecto     https://www.gsmarena.com/unnecto-phones-91.php
# 92         VK Mobile   https://www.gsmarena.com/vk_mobile-phones-37.php
# 93             Vertu       https://www.gsmarena.com/vertu-phones-39.php
# 94          Vodafone    https://www.gsmarena.com/vodafone-phones-53.php
# 95               WND         https://www.gsmarena.com/wnd-phones-51.php
# 96              Wiko        https://www.gsmarena.com/wiko-phones-96.php
# 97             XCute       https://www.gsmarena.com/xcute-phones-43.php
# 98              XOLO        https://www.gsmarena.com/xolo-phones-85.php
# 99            Xiaomi      https://www.gsmarena.com/xiaomi-phones-80.php
# 100               YU         https://www.gsmarena.com/yu-phones-100.php
# 101             Yezz        https://www.gsmarena.com/yezz-phones-78.php
# 102             Yota        https://www.gsmarena.com/yota-phones-99.php
# 103              ZTE         https://www.gsmarena.com/zte-phones-62.php
# 104          alcatel      https://www.gsmarena.com/alcatel-phones-5.php
# 105           i-mate      https://www.gsmarena.com/i_mate-phones-35.php
# 106         i-mobile    https://www.gsmarena.com/i_mobile-phones-52.php
# 107              iNQ         https://www.gsmarena.com/inq-phones-60.php
# 108         verykool    https://www.gsmarena.com/verykool-phones-70.php
# 109             vivo        https://www.gsmarena.com/vivo-phones-98.php
#
#      results_n  n_models
# 0            4         4
# 1          100       100
# 2          134       134
# 3           17        17
# 4           47        47
# 5           63        63
# 6           39        39
# 7          169       169
# 8          279       279
# 9           20        20
# 10          35        35
# 11          27        27
# 12           9         9
# 13          61        61
# 14          92        92
# 15           6         6
# 16          10        10
# 17           5         5
# 18          13        13
# 19         229       229
# 20          12        12
# 21          28        28
# 22          20        20
# 23          15        15
# 24          25        25
# 25          40        40
# 26          22        22
# 27           2         2
# 28           5         5
# 29          63        63
# ..         ...       ...
# 80          56        56
# 81          94        94
# 82          14        14
# 83         136       137
# 84         188       188
# 85         120       120
# 86          53        53
# 87           7         7
# 88          30        30
# 89           1         1
# 90          35        35
# 91          30        30
# 92          31        31
# 93          17        17
# 94          83        83
# 95           5         5
# 96          63        63
# 97           4         4
# 98          80        81
# 99          80        80
# 100         13        13
# 101         87        87
# 102          3         3
# 103        240       246
# 104        378       378
# 105         34        34
# 106         37        37
# 107          5         5
# 108        139       139
# 109         72        72
#
# [110 rows x 4 columns]

# %%
final_df.head()
print (final_df.shape) # all brands accounted for
# Out:
# (110, 4)

# %% [markdown]
# # Missing models

# %%
final_df.columns
# Out:
# Index(['brand', 'url', 'results_n', 'n_models'], dtype='object')

# %%
# fail safe for additional models added, must be something wrong with pages
mask = final_df['results_n'] != final_df['n_models']
final_df.where(mask).dropna(axis=0, how='all')
# Out:
#         brand                                             url  results_n  \
# 35     Huawei   https://www.gsmarena.com/huawei-phones-58.php      288.0
# 45     Lenovo   https://www.gsmarena.com/lenovo-phones-73.php      180.0
# 55   Motorola  https://www.gsmarena.com/motorola-phones-4.php      459.0
# 59      Nokia     https://www.gsmarena.com/nokia-phones-1.php      465.0
# 61          O       https://www.gsmarena.com/o2-phones-30.php       45.0
# 62    OnePlus  https://www.gsmarena.com/oneplus-phones-95.php        8.0
# 65       Palm     https://www.gsmarena.com/palm-phones-27.php       16.0
# 77    Samsung   https://www.gsmarena.com/samsung-phones-9.php     1155.0
# 83       Sony      https://www.gsmarena.com/sony-phones-7.php      136.0
# 98       XOLO     https://www.gsmarena.com/xolo-phones-85.php       80.0
# 103       ZTE      https://www.gsmarena.com/zte-phones-62.php      240.0
#
#      n_models
# 35      289.0
# 45      181.0
# 55      461.0
# 59      467.0
# 61      245.0
# 62        9.0
# 65       17.0
# 77     1157.0
# 83      137.0
# 98       81.0
# 103     246.0

# %% [markdown]
# # Completed

# %%
final_df.where(~mask).dropna(axis=0, how = 'all')
# Out:
#                brand                                                url  \
# 0              AT&T;        https://www.gsmarena.com/at&t-phones-57.php
# 1               Acer        https://www.gsmarena.com/acer-phones-59.php
# 2            Allview     https://www.gsmarena.com/allview-phones-88.php
# 3             Amazon      https://www.gsmarena.com/amazon-phones-76.php
# 4               Amoi        https://www.gsmarena.com/amoi-phones-28.php
# 5              Apple       https://www.gsmarena.com/apple-phones-48.php
# 6             Archos      https://www.gsmarena.com/archos-phones-90.php
# 7               Asus        https://www.gsmarena.com/asus-phones-46.php
# 8                BLU         https://www.gsmarena.com/blu-phones-67.php
# 9                 BQ         https://www.gsmarena.com/bq-phones-108.php
# 10              BenQ        https://www.gsmarena.com/benq-phones-31.php
# 11      BenQ-Siemens  https://www.gsmarena.com/benq_siemens-phones-4...
# 12           Benefon     https://www.gsmarena.com/benefon-phones-15.php
# 13              Bird        https://www.gsmarena.com/bird-phones-34.php
# 14        BlackBerry  https://www.gsmarena.com/blackberry-phones-36.php
# 15         Blackview  https://www.gsmarena.com/blackview-phones-116.php
# 16             Bosch       https://www.gsmarena.com/bosch-phones-10.php
# 17             Casio       https://www.gsmarena.com/casio-phones-77.php
# 18               Cat         https://www.gsmarena.com/cat-phones-89.php
# 19            Celkon      https://www.gsmarena.com/celkon-phones-75.php
# 20              Chea        https://www.gsmarena.com/chea-phones-24.php
# 21           Coolpad    https://www.gsmarena.com/coolpad-phones-105.php
# 22              Dell        https://www.gsmarena.com/dell-phones-61.php
# 23           Emporia     https://www.gsmarena.com/emporia-phones-93.php
# 24         Energizer  https://www.gsmarena.com/energizer-phones-106.php
# 25          Ericsson     https://www.gsmarena.com/ericsson-phones-2.php
# 26              Eten        https://www.gsmarena.com/eten-phones-40.php
# 27   Fujitsu Siemens  https://www.gsmarena.com/fujitsu_siemens-phone...
# 28       Garmin-Asus  https://www.gsmarena.com/garmin_asus-phones-65...
# 29          Gigabyte    https://www.gsmarena.com/gigabyte-phones-47.php
# ..               ...                                                ...
# 76             Sagem       https://www.gsmarena.com/sagem-phones-13.php
# 78             Sendo       https://www.gsmarena.com/sendo-phones-18.php
# 79             Sewon       https://www.gsmarena.com/sewon-phones-26.php
# 80             Sharp       https://www.gsmarena.com/sharp-phones-23.php
# 81           Siemens      https://www.gsmarena.com/siemens-phones-3.php
# 82             Sonim       https://www.gsmarena.com/sonim-phones-54.php
# 84     Sony Ericsson  https://www.gsmarena.com/sony_ericsson-phones-...
# 85             Spice       https://www.gsmarena.com/spice-phones-68.php
# 86          T-Mobile    https://www.gsmarena.com/t_mobile-phones-55.php
# 87           Tel.Me.     https://www.gsmarena.com/tel_me_-phones-21.php
# 88             Telit       https://www.gsmarena.com/telit-phones-16.php
# 89           Thuraya     https://www.gsmarena.com/thuraya-phones-49.php
# 90           Toshiba     https://www.gsmarena.com/toshiba-phones-44.php
# 91           Unnecto     https://www.gsmarena.com/unnecto-phones-91.php
# 92         VK Mobile   https://www.gsmarena.com/vk_mobile-phones-37.php
# 93             Vertu       https://www.gsmarena.com/vertu-phones-39.php
# 94          Vodafone    https://www.gsmarena.com/vodafone-phones-53.php
# 95               WND         https://www.gsmarena.com/wnd-phones-51.php
# 96              Wiko        https://www.gsmarena.com/wiko-phones-96.php
# 97             XCute       https://www.gsmarena.com/xcute-phones-43.php
# 99            Xiaomi      https://www.gsmarena.com/xiaomi-phones-80.php
# 100               YU         https://www.gsmarena.com/yu-phones-100.php
# 101             Yezz        https://www.gsmarena.com/yezz-phones-78.php
# 102             Yota        https://www.gsmarena.com/yota-phones-99.php
# 104          alcatel      https://www.gsmarena.com/alcatel-phones-5.php
# 105           i-mate      https://www.gsmarena.com/i_mate-phones-35.php
# 106         i-mobile    https://www.gsmarena.com/i_mobile-phones-52.php
# 107              iNQ         https://www.gsmarena.com/inq-phones-60.php
# 108         verykool    https://www.gsmarena.com/verykool-phones-70.php
# 109             vivo        https://www.gsmarena.com/vivo-phones-98.php
#
#      results_n  n_models
# 0          4.0       4.0
# 1        100.0     100.0
# 2        134.0     134.0
# 3         17.0      17.0
# 4         47.0      47.0
# 5         63.0      63.0
# 6         39.0      39.0
# 7        169.0     169.0
# 8        279.0     279.0
# 9         20.0      20.0
# 10        35.0      35.0
# 11        27.0      27.0
# 12         9.0       9.0
# 13        61.0      61.0
# 14        92.0      92.0
# 15         6.0       6.0
# 16        10.0      10.0
# 17         5.0       5.0
# 18        13.0      13.0
# 19       229.0     229.0
# 20        12.0      12.0
# 21        28.0      28.0
# 22        20.0      20.0
# 23        15.0      15.0
# 24        25.0      25.0
# 25        40.0      40.0
# 26        22.0      22.0
# 27         2.0       2.0
# 28         5.0       5.0
# 29        63.0      63.0
# ..         ...       ...
# 76       120.0     120.0
# 78        19.0      19.0
# 79        25.0      25.0
# 80        56.0      56.0
# 81        94.0      94.0
# 82        14.0      14.0
# 84       188.0     188.0
# 85       120.0     120.0
# 86        53.0      53.0
# 87         7.0       7.0
# 88        30.0      30.0
# 89         1.0       1.0
# 90        35.0      35.0
# 91        30.0      30.0
# 92        31.0      31.0
# 93        17.0      17.0
# 94        83.0      83.0
# 95         5.0       5.0
# 96        63.0      63.0
# 97         4.0       4.0
# 99        80.0      80.0
# 100       13.0      13.0
# 101       87.0      87.0
# 102        3.0       3.0
# 104      378.0     378.0
# 105       34.0      34.0
# 106       37.0      37.0
# 107        5.0       5.0
# 108      139.0     139.0
# 109       72.0      72.0
#
# [99 rows x 4 columns]
